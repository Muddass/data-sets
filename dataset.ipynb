# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %%
dataset=pd.DataFrame(pd.read_excel("ab.xlsx"))

# %%
dataset
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 191  1022         1        2005.0            7.0        Apartment          22
# 192  1028         1        2005.0            7.0        Apartment          28
# 193  1034         1        2005.0            7.0        Apartment          34
# 194  1037         1        2005.0            7.0        Apartment          37
# 195  1042         1        2005.0            7.0        Apartment          42
#
# ...

# %%
dataset.describe()
# Out:
#                 ID    Building  Year of sale  Month of sale  Property #  \
# count   196.000000  196.000000    195.000000     195.000000  196.000000
# mean   2603.979592    2.576531   2006.333333       7.271795   27.454082
# std    1253.802184    1.252387      1.072941       3.378674   14.897356
# min    1002.000000    1.000000   2004.000000       1.000000    1.000000
# 25%    2003.750000    2.000000   2006.000000       4.000000   15.000000
# 50%    2055.000000    2.000000   2007.000000       8.000000   27.500000
# 75%    3049.250000    3.000000   2007.000000      10.000000   39.250000
# max    5052.000000    5.000000   2010.000000      12.000000   59.000000
#
#         Area (ft.)          Price            Y           M           D  \
# count   196.000000     196.000000   178.000000  178.000000  178.000000
# mean    904.303835  270778.657071  1960.325843    6.752809   15.449438
# std     268.112770   82108.694230    12.835575    3.450312    8.457285
# ...

# %%
dataset.dtypes
# Out:
# ID                           int64
# Building                     int64
# Year of sale               float64
# Month of sale              float64
# Type of property            object
# Property #                   int64
# Area (ft.)                 float64
# Price                      float64
# Status                      object
# Customer ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
dataset["Gender"][(dataset["Gender"]=="M")].value_counts()
# Out:
# M    108
# Name: Gender, dtype: int64

# %%
dataset["Gender"][(dataset["Gender"]=="F")].value_counts()
# Out:
# F    70
# Name: Gender, dtype: int64

# %%
dataset['Gender'][dataset["Gender"].isna()]
# Out:
# 178    NaN
# 179    NaN
# 180    NaN
# 181    NaN
# 182    NaN
# 183    NaN
# 184    NaN
# 185    NaN
# 186    NaN
# 187    NaN
# 188    NaN
# 189    NaN
# 190    NaN
# 191    NaN
# 192    NaN
# 193    NaN
# 194    NaN
# 195    NaN
# Name: Gender, dtype: object

# %%
dataset[dataset["Gender"].isna()].count()
# Out:
# ID                         18
# Building                   18
# Year of sale               17
# Month of sale              17
# Type of property           18
# Property #                 18
# Area (ft.)                 18
# Price                      18
# Status                     17
# Customer ID                17
# Entity                     17
# Name                       17
# Surname                    17
# Age at time of purchase     1
# Interval                    0
# Y                           0
# M                           0
# D                           0
# Gender                      0
# Country                    17
# State                      17
# Purpose                    17
# Deal satisfaction          17
# Mortgage                   17
# Source                     17
# dtype: int64

# %%
dataset["Gender"][dataset["Gender"].isna()]="Firm"
# Out:
# <ipython-input-18-b3e71bc669c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Gender"][dataset["Gender"].isna()]="Firm"

# %%
dataset["Gender"]
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 191    Firm
# 192    Firm
# 193    Firm
# 194    Firm
# 195    Firm
# Name: Gender, Length: 196, dtype: object

# %%
dataset
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 191  1022         1        2005.0            7.0        Apartment          22
# 192  1028         1        2005.0            7.0        Apartment          28
# 193  1034         1        2005.0            7.0        Apartment          34
# 194  1037         1        2005.0            7.0        Apartment          37
# 195  1042         1        2005.0            7.0        Apartment          42
#
# ...

# %%
total=dataset["Gender"].count()
total
# Out:
# 196

# %%
dataset["Gender"].groupby(dataset["Gender"]).count()
# Out:
# Gender
# F        70
# Firm     18
# M       108
# Name: Gender, dtype: int64

# %%
(femaleFrequency,firmFrequency,maleFrequency)=dataset["Gender"].groupby(dataset["Gender"]).count()

# %%
femaleFrequency
# Out:
# 70

# %%
firmFrequency
# Out:
# 18

# %%
maleFrequency
# Out:
# 108

# %%
tabel_gender=pd.DataFrame({"Male":[male],"Female":[Female],"Firm":[Firm]})

# %%
tabel_gender
# Out:
#    Male  Female  Firm
# 0   108      70    18

# %%
aa=pd.DataFrame(dataset["Gender"].groupby(dataset["Gender"]).count())

# %%
aa
# Out:
#         Gender
# Gender
# F           70
# Firm        18
# M          108

# %%
Frequency = [maleFrequency, femaleFrequency, firmFrequency, total]
RelativeFrequecy = [int(maleFrequency/total*100), int(femaleFrequency/total*100), int(firmFrequency/total*100), 100]
genderTable = pd.DataFrame({'Frequency': Frequency, 'Relative Frequency': RelativeFrequecy}, index=['Male', 'Female', 'Firms', 'Total'])

# %%
genderTable
# Out:
#         Frequency  Relative Frequency
# Male          108                  55
# Female         70                  35
# Firms          18                   9
# Total         196                 100

# %%
genderTable.plot(y='Frequency',kind='pie')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
genderTable.plot(y='Relative Frequency',kind='pie')
# Out:
# <AxesSubplot:ylabel='Relative Frequency'>

# %%
dataset['Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>
