# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('data.csv')

# %%
del dataset['Unnamed: 10']

# %%
dataset
# Out:
#     Unnamed: 0    ID  Building  Year of sale  Month of sale Type of property  \
# 0          NaN  1030         1        2005.0           11.0        Apartment
# 1          NaN  1029         1        2005.0           10.0        Apartment
# 2          NaN  2002         2        2007.0            7.0        Apartment
# 3          NaN  2031         2        2007.0           12.0        Apartment
# 4          NaN  1049         1        2004.0           11.0        Apartment
# ..         ...   ...       ...           ...            ...              ...
# 262        NaN  5044         5           NaN            NaN        Apartment
# 263        NaN  5047         5           NaN            NaN        Apartment
# 264        NaN  5048         5           NaN            NaN        Apartment
# 265        NaN  5050         5           NaN            NaN        Apartment
# 266        NaN  5051         5           NaN            NaN        Apartment
#
# ...

# %%
dataset.describe()
# Out:
#                 ID    Building  Year of sale  Month of sale  Property #  \
# count   267.000000  267.000000    195.000000     195.000000  267.000000
# mean   2975.142322    2.947566   2006.333333       7.271795   27.580524
# std    1392.197474    1.391794      1.072941       3.378674   15.361437
# min    1002.000000    1.000000   2004.000000       1.000000    1.000000
# 25%    2015.500000    2.000000   2006.000000       4.000000   14.500000
# 50%    3024.000000    3.000000   2007.000000       8.000000   28.000000
# 75%    4031.500000    4.000000   2007.000000      10.000000   40.000000
# max    5052.000000    5.000000   2010.000000      12.000000   59.000000
#
#         Area (ft.)          Price            Y           M           D  \
# count   267.000000     267.000000   178.000000  178.000000  178.000000
# mean    936.221311  281171.901386  1960.325843    6.752809   15.449438
# std     284.894858   89119.121005    12.835575    3.450312    8.457285
# ...

# %%
dataset.dtypes
# Out:
# Unnamed: 0                  object
# ID                           int64
# Building                     int64
# Year of sale               float64
# Month of sale              float64
# Type of property            object
# Property #                   int64
# Area (ft.)                 float64
# Price                      float64
# Status                      object
# Customer ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0                 266
# ID                           0
# Building                     0
# Year of sale                72
# Month of sale               72
# Type of property             0
# Property #                   0
# Area (ft.)                   0
# Price                        0
# Status                      72
# Customer ID                 72
# Entity                      72
# Name                        72
# Surname                     72
# Age at time of purchase     88
# Interval                    89
# Y                           89
# M                           89
# D                           89
# Gender                      89
# Country                     72
# State                       86
# Purpose                     72
# Deal satisfaction           72
# Mortgage                    72
# Source                      72
# dtype: int64

# %%
data2=dataset.copy()

# %%
dataset=data2.copy() # copy data again

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Building', 'Year of sale', 'Month of sale',
#        'Type of property', 'Property #', 'Area (ft.)', 'Price', 'Status',
#        'Customer ID', 'Entity', 'Name', 'Surname', 'Age at time of purchase',
#        'Interval', 'Y', 'M', 'D', 'Gender', 'Country', 'State', 'Purpose',
#        'Deal satisfaction', 'Mortgage', 'Source'],
#       dtype='object')

# %%
dataset['Year of sale']=dataset['Year of sale'].replace(np.nan,0)

# %%
dataset
# Out:
#     Unnamed: 0    ID  Building  Year of sale  Month of sale Type of property  \
# 0          NaN  1030         1        2005.0           11.0        Apartment
# 1          NaN  1029         1        2005.0           10.0        Apartment
# 2          NaN  2002         2        2007.0            7.0        Apartment
# 3          NaN  2031         2        2007.0           12.0        Apartment
# 4          NaN  1049         1        2004.0           11.0        Apartment
# ..         ...   ...       ...           ...            ...              ...
# 262        NaN  5044         5           0.0            NaN        Apartment
# 263        NaN  5047         5           0.0            NaN        Apartment
# 264        NaN  5048         5           0.0            NaN        Apartment
# 265        NaN  5050         5           0.0            NaN        Apartment
# 266        NaN  5051         5           0.0            NaN        Apartment
#
# ...

# %%
dataset.dtypes
# Out:
# Unnamed: 0                  object
# ID                           int64
# Building                     int64
# Year of sale               float64
# Month of sale              float64
# Type of property            object
# Property #                   int64
# Area (ft.)                 float64
# Price                      float64
# Status                      object
# Customer ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
dataset['Gender'].fillna('Firm',inplace=True)

# %%
dataset['Gender']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 262    Firm
# 263    Firm
# 264    Firm
# 265    Firm
# 266    Firm
# Name: Gender, Length: 267, dtype: object

# %%
dataset['Gender'].value_counts()
# Out:
# M       108
# Firm     89
# F        70
# Name: Gender, dtype: int64

# %%
dataset['Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>
